# %% [markdown]
# <a href="https://colab.research.google.com/github/MattStarDew/PUC/blob/main/EJERCICIO_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EJERCICIO 1:**

# %% [markdown]
# 1.   Loading an image
# 2.   Converting an image into grayscale
# 3.   Histogram

# %% [markdown]
# First image in color

# %%
import skimage as sk # load skimage libraries
from skimage import io

file_path = '/content/degas.jpg'
I1 = sk.io.imread(file_path) # read image using imread function
print(I1.dtype)
sk.io.imshow(I1) # visualize image using imshow function
sk.io.show()
print('M = {} columns, N = {} rows, NC = {} color channels'.format(*I1.shape)) # Print out image size
# Out:
# uint8
# M = 520 columns, N = 1200 rows, NC = 3 color channels

# %% [markdown]
# Second image, conversion to grayscale

# %%
import matplotlib.pyplot as plt
import numpy as np

file_path = '/content/vangogh.jpg'
I2 = sk.io.imread(file_path) # read image using imread function
print('The original image is type:', I2.dtype)
print('M = {} columns, N = {} rows, NC = {} color channels'.format(*I2.shape)) # Print out image size

IG = sk.color.rgb2gray(I2)
print('The grayscale image is type:',IG.dtype)

fig = plt.figure(figsize=(14, 6))
plt.subplot(121)
plt.imshow(I2) # visualize image using imshow function, always colour
plt.title('Original image')

plt.subplot(122)
sk.io.imshow(IG) # visualize image using imshow function
plt.title('Grayscale image')
plt.show()
# Out:
# The original image is type: uint8
# M = 1200 columns, N = 921 rows, NC = 3 color channels
# The grayscale image is type: float64

# %% [markdown]
# Creating a histogram

# %%
# reshape the uint8 image as 1d array:
v = IG.reshape(IG.shape[0]*IG.shape[1],1)

fig = plt.figure(figsize=(14, 6))
plt.hist(v, bins=256,density=False)
plt.show()
